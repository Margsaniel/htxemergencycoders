# %%
# Dependencies and setup
# %matplotlib inline
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv
reservoirs_and_bayou_df = pd.read_csv('../data/clean_data/reservoirs_and_bayou.csv')
reservoirs_and_bayou_df.head()
# Out:
#        Date  Addicks storage (acre ft)  Addicks  elevation (ft)  \
# 0  1/1/2017                        NaN                    77.55
# 1  1/2/2017                        NaN                    80.78
# 2  1/3/2017                        NaN                    83.34
# 3  1/4/2017                        NaN                    83.08
# 4  1/5/2017                        NaN                    80.48
#
#    Addicks rain (in)  Barker storage (acre ft)  Barker elevation (ft)  \
# 0               0.00                     61.08                  78.24
# 1               0.52                    265.60                  78.96
# 2               0.00                    103.70                  79.86
# 3               0.00                    642.80                  79.94
# 4               0.00                    379.70                  78.86
#
#    Barker rain (in)  Dairy Ashford rain (in)  Beltway 8 rain (in)  \
# 0              0.00                     0.00                 0.00
# ...

# %%
# Replace all NaN values with 0 
reservoirs_and_bayou_df = reservoirs_and_bayou_df.fillna(0)

# Set index of dataframe to be "Date" of calendar year 2017
reservoirs_and_bayou_df.set_index("Date").head()
# Out:
#           Addicks storage (acre ft)  Addicks  elevation (ft)  \
# Date
# 1/1/2017                        0.0                    77.55
# 1/2/2017                        0.0                    80.78
# 1/3/2017                        0.0                    83.34
# 1/4/2017                        0.0                    83.08
# 1/5/2017                        0.0                    80.48
#
#           Addicks rain (in)  Barker storage (acre ft)  Barker elevation (ft)  \
# Date
# 1/1/2017               0.00                     61.08                  78.24
# 1/2/2017               0.52                    265.60                  78.96
# 1/3/2017               0.00                    103.70                  79.86
# 1/4/2017               0.00                    642.80                  79.94
# 1/5/2017               0.00                    379.70                  78.86
#
#           Barker rain (in)  Dairy Ashford rain (in)  Beltway 8 rain (in)  \
# Date
# ...

# %%
# Create a list of the years that we will use as our x axis
x_axis =
