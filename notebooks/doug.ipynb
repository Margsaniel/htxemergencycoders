# %%
# Dependencies and setup
# %matplotlib inline
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv
reservoirs_and_bayou_df = pd.read_csv('../data/clean_data/reservoirs_and_bayou.csv')
reservoirs_and_bayou_df.head()
# Out:
#        Date  Addicks storage (acre ft)  Addicks elevation (ft)  \
# 0       JAN                          0                   77.55
# 1  1/2/2017                          0                   80.78
# 2  1/3/2017                          0                   83.34
# 3  1/4/2017                          0                   83.08
# 4  1/5/2017                          0                   80.48
#
#    Addicks rain (in)  Barker storage (acre ft)  Barker elevation (ft)  \
# 0               0.00                     61.08                  78.24
# 1               0.52                    265.60                  78.96
# 2               0.00                    103.70                  79.86
# 3               0.00                    642.80                  79.94
# 4               0.00                    379.70                  78.86
#
#    Barker rain (in)  Dairy Ashford rain (in)  Beltway 8 rain (in)  \
# 0              0.00                     0.00                 0.00
# ...

# %%
# Set index of dataframe to be "Date" for year 2017
reservoirs_and_bayou_df.set_index("Date").head()
# Out:
#           Addicks storage (acre ft)  Addicks elevation (ft)  \
# Date
# JAN                               0                   77.55
# 1/2/2017                          0                   80.78
# 1/3/2017                          0                   83.34
# 1/4/2017                          0                   83.08
# 1/5/2017                          0                   80.48
#
#           Addicks rain (in)  Barker storage (acre ft)  Barker elevation (ft)  \
# Date
# JAN                    0.00                     61.08                  78.24
# 1/2/2017               0.52                    265.60                  78.96
# 1/3/2017               0.00                    103.70                  79.86
# 1/4/2017               0.00                    642.80                  79.94
# 1/5/2017               0.00                    379.70                  78.86
#
#           Barker rain (in)  Dairy Ashford rain (in)  Beltway 8 rain (in)  \
# Date
# ...

# %%
# Create a list of dates and elevations for Addicks Reservoir
x = reservoirs_and_bayou_df["Date"]
y1 = reservoirs_and_bayou_df["Addicks elevation (ft)"]
y2 = reservoirs_and_bayou_df["Addicks rain (in)"]

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(x, y1, "b-")
ax2.plot(x, y2, "r-")

ax1.set_xlabel("")
ax1.set_ylabel("ELEVATION  (FT)", color="b")
ax2.set_ylabel("RAIN  FALL  (IN)", color="r", rotation=270, labelpad=15)

plt.title("2017 Addicks Reservoir Elevation and Rain Fall")

frequency = 30

plt.xticks(x[::frequency],rotation=45)
plt.grid()

#plt.axhline(y=95, color='r', linestyle='-')
#plt.text(95, 95, "Top of Spillway", fontsize=10, va='center', ha='center', backgroundcolor='w')
#plt.axhline(y=88, color='r', linestyle='-')
#plt.text(88, 88, "Highway 6 Flooding", fontsize=10, va='center', ha='center', backgroundcolor='w')

plt.savefig("../images/addicks_reservoir_elevation.png")
plt.show()

# %%
# Create a list of dates and elevations for Barker Reservoir
x = reservoirs_and_bayou_df["Date"]
y1 = reservoirs_and_bayou_df["Barker elevation (ft)"]
y2 = reservoirs_and_bayou_df["Barker rain (in)"]

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(x, y1, "b-")
ax2.plot(x, y2, "r-")

ax1.set_xlabel("")
ax1.set_ylabel("ELEVATION  (FT)", color="b")
ax2.set_ylabel("RAIN  F  (IN)", color="r", rotation=270, labelpad=15)

plt.title("2017 Barker Reservoir Elevation and Rain Fall")

frequency = 30

plt.xticks(x[::frequency],rotation=45)
plt.grid()

#plt.axhline(y=104, color='r', linestyle='-')
#plt.text(104, 104, "Top of Spillway", fontsize=10, va='center', ha='center', backgroundcolor='w')
#plt.axhline(y=96, color='r', linestyle='-')
#plt.text(96, 96, " House Flooding", fontsize=10, va='center', ha='center', backgroundcolor='w')

plt.savefig("../images/barker_reservoir_elevation.png")
plt.show()
